# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.rc('font', **{'family': 'Arial', 'size': 14})

# %%
team_ranking = pd.read_csv('test.csv')
team_ranking.head(9)
# Out:
#    Platz                    Team  Spiele  Punkte  2er  3er  Fieldgoals  FWM  \
# 0      1            TSV Essingen      16    1294  352  127         479  209
# 1      2           Tb Ruit Deers      16    1163  386   77         463  160
# 2      4          TSV Schmiden 2      16    1050  285  114         399  138
# 3      3            ASV Aichwald      16    1025  349   57         406  156
# 4      6       SpVgg Möhringen 2      16    1009  355   45         400  164
# 5      5  TSB Schwäbisch Gmünd 2      16     880  260   79         339  123
# 6      7           SG Schorndorf      16     871  215  107         322  120
# 7      8    Aalener Sportallianz      16     860  248   69         317  157
# 8      9     Sportvg Feuerbach 3      16     754  257   47         304   99
#
#    FWA   FW %  Fouls   EFF
# 0  364  57,4%    264  1618
# 1  300  53,3%    268  1486
# 2  270  51,1%    233  1317
# 3  292  53,4%    274  1295
# 4  291  56,4%    262  1282
# 5  268  45,9%    279  1074
# ...

# %%
plt.bar(team_ranking['Platz'], team_ranking['FW %'])
plt.xlabel('Platz')
plt.ylabel('FW %')
plt.title('FW % nach Platz')
